# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("city_temperature.csv")

# %%
data.head()
# Out:
#    Region  Country State     City  Month  Day  Year  AvgTemperature
# 0  Africa  Algeria   NaN  Algiers      1    1  1995            64.2
# 1  Africa  Algeria   NaN  Algiers      1    2  1995            49.4
# 2  Africa  Algeria   NaN  Algiers      1    3  1995            48.8
# 3  Africa  Algeria   NaN  Algiers      1    4  1995            46.4
# 4  Africa  Algeria   NaN  Algiers      1    5  1995            47.9

# %%
data.dtypes
# Out:
# Region             object
# Country            object
# State              object
# City               object
# Month               int64
# Day                 int64
# Year                int64
# AvgTemperature    float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906327 entries, 0 to 2906326
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Region          object
#  1   Country         object
#  2   State           object
#  3   City            object
#  4   Month           int64
#  5   Day             int64
#  6   Year            int64
#  7   AvgTemperature  float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 177.4+ MB

# %%
data.describe()
# Out:
#               Month           Day          Year  AvgTemperature
# count  2.906327e+06  2.906327e+06  2.906327e+06    2.906327e+06
# mean   6.469163e+00  1.571682e+01  2.006624e+03    5.600492e+01
# std    3.456489e+00  8.800534e+00  2.338226e+01    3.212359e+01
# min    1.000000e+00  0.000000e+00  2.000000e+02   -9.900000e+01
# 25%    3.000000e+00  8.000000e+00  2.001000e+03    4.580000e+01
# 50%    6.000000e+00  1.600000e+01  2.007000e+03    6.250000e+01
# 75%    9.000000e+00  2.300000e+01  2.013000e+03    7.550000e+01
# max    1.200000e+01  3.100000e+01  2.020000e+03    1.100000e+02

# %%
data.shape
# Out:
# (2906327, 8)

# %%
data.isna().sum()
# Out:
# Region                  0
# Country                 0
# State             1450990
# City                    0
# Month                   0
# Day                     0
# Year                    0
# AvgTemperature          0
# dtype: int64

# %%
data.isna().sum () / data.shape[0] * 100
# Out:
# Region             0.000000
# Country            0.000000
# State             49.925215
# City               0.000000
# Month              0.000000
# Day                0.000000
# Year               0.000000
# AvgTemperature     0.000000
# dtype: float64

# %%
data_prepared = data.dropna()

# %%
data.shape
# Out:
# (2906327, 8)

# %%
data_prepared.shape
# Out:
# (1455337, 8)

# %%
data.head()
# Out:
#    Region  Country State     City  Month  Day  Year  AvgTemperature
# 0  Africa  Algeria   NaN  Algiers      1    1  1995            64.2
# 1  Africa  Algeria   NaN  Algiers      1    2  1995            49.4
# 2  Africa  Algeria   NaN  Algiers      1    3  1995            48.8
# 3  Africa  Algeria   NaN  Algiers      1    4  1995            46.4
# 4  Africa  Algeria   NaN  Algiers      1    5  1995            47.9

# %%
data_prepared.dropna(axis=0, how='any')
# Out:
#                 Region Country                   State                  City  \
# 1450990  North America      US                 Alabama            Birmingham
# 1450991  North America      US                 Alabama            Birmingham
# 1450992  North America      US                 Alabama            Birmingham
# 1450993  North America      US                 Alabama            Birmingham
# 1450994  North America      US                 Alabama            Birmingham
# ...                ...     ...                     ...                   ...
# 2906322  North America      US  Additional Territories  San Juan Puerto Rico
# 2906323  North America      US  Additional Territories  San Juan Puerto Rico
# 2906324  North America      US  Additional Territories  San Juan Puerto Rico
# 2906325  North America      US  Additional Territories  San Juan Puerto Rico
# 2906326  North America      US  Additional Territories  San Juan Puerto Rico
#
#          Month  Day  Year  AvgTemperature
# ...

# %%
data_prepared.shape
# Out:
# (1455337, 8)

# %%
data_prepared.isna().sum()#herhangi bir nan değeri olmadıgını görürüz.
# Out:
# Region            0
# Country           0
# State             0
# City              0
# Month             0
# Day               0
# Year              0
# AvgTemperature    0
# dtype: int64

# %%
data_prepared.head()
# Out:
#                 Region Country    State        City  Month  Day  Year  \
# 1450990  North America      US  Alabama  Birmingham      1    1  1995
# 1450991  North America      US  Alabama  Birmingham      1    2  1995
# 1450992  North America      US  Alabama  Birmingham      1    3  1995
# 1450993  North America      US  Alabama  Birmingham      1    4  1995
# 1450994  North America      US  Alabama  Birmingham      1    5  1995
#
#          AvgTemperature
# 1450990            50.7
# 1450991            37.2
# 1450992            33.2
# 1450993            33.3
# 1450994            26.4

# %%
data_prepared[['City']]#tekk[] pandas serisi olarak alır. çift[[]] dataframe olarak alır.
# Out:
#                          City
# 1450990            Birmingham
# 1450991            Birmingham
# 1450992            Birmingham
# 1450993            Birmingham
# 1450994            Birmingham
# ...                       ...
# 2906322  San Juan Puerto Rico
# 2906323  San Juan Puerto Rico
# 2906324  San Juan Puerto Rico
# 2906325  San Juan Puerto Rico
# 2906326  San Juan Puerto Rico
#
# [1455337 rows x 1 columns]

# %%
data_prepared[['City','State']]
# Out:
#                          City                   State
# 1450990            Birmingham                 Alabama
# 1450991            Birmingham                 Alabama
# 1450992            Birmingham                 Alabama
# 1450993            Birmingham                 Alabama
# 1450994            Birmingham                 Alabama
# ...                       ...                     ...
# 2906322  San Juan Puerto Rico  Additional Territories
# 2906323  San Juan Puerto Rico  Additional Territories
# 2906324  San Juan Puerto Rico  Additional Territories
# 2906325  San Juan Puerto Rico  Additional Territories
# 2906326  San Juan Puerto Rico  Additional Territories
#
# [1455337 rows x 2 columns]

# %%
data_prepared['State'].value_counts() #groupby gibi hangi degerden kaç tane olduğunu verir.
# Out:
# Texas                     129711
# Ohio                       64855
# Florida                    61341
# Pennsylvania               52076
# Michigan                   46325
# California                 46325
# New York                   46325
# Alabama                    37060
# Illinois                   37060
# Colorado                   37060
# Tennessee                  37060
# Indiana                    37060
# North Carolina             37060
# Oregon                     37060
# Georgia                    37060
# Louisiana                  33593
# Kansas                     27795
# Kentucky                   27795
# Virginia                   27795
# Missouri                   27795
# Nebraska                   27795
# Washington                 27795
# Maryland                   27795
# Wisconsin                  27795
# Alaska                     27795
# Montana                    27794
# Arizona                    26484
# Idaho                      18530
# ...

# %%
data_prepared['State'] == 'Nevada' #aralarda biryerde true geliyor
# Out:
# 1450990    False
# 1450991    False
# 1450992    False
# 1450993    False
# 1450994    False
#            ...
# 2906322    False
# 2906323    False
# 2906324    False
# 2906325    False
# 2906326    False
# Name: State, Length: 1455337, dtype: bool

# %%
data_prepared[(data_prepared['State'] == 'Nevada') | (data_prepared['State'] == 'Utah') ]
# Out:
#                 Region Country   State            City  Month  Day  Year  \
# 2217443  North America      US  Nevada            Reno      1    1  1995
# 2217444  North America      US  Nevada            Reno      1    2  1995
# 2217445  North America      US  Nevada            Reno      1    3  1995
# 2217446  North America      US  Nevada            Reno      1    4  1995
# 2217447  North America      US  Nevada            Reno      1    5  1995
# ...                ...     ...     ...             ...    ...  ...   ...
# 2769825  North America      US    Utah  Salt Lake City      5    9  2020
# 2769826  North America      US    Utah  Salt Lake City      5   10  2020
# 2769827  North America      US    Utah  Salt Lake City      5   11  2020
# 2769828  North America      US    Utah  Salt Lake City      5   12  2020
# 2769829  North America      US    Utah  Salt Lake City      5   13  2020
#
#          AvgTemperature
# 2217443            29.3
# 2217444            27.1
# ...

# %%
data_prepared[(data_prepared['State'] == 'Nevada') & (data_prepared['Month'] > 3) ] #marttan sonraki aylar
# Out:
#                 Region Country   State       City  Month  Day  Year  \
# 2217533  North America      US  Nevada       Reno      4    1  1995
# 2217534  North America      US  Nevada       Reno      4    2  1995
# 2217535  North America      US  Nevada       Reno      4    3  1995
# 2217536  North America      US  Nevada       Reno      4    4  1995
# 2217537  North America      US  Nevada       Reno      4    5  1995
# ...                ...     ...     ...        ...    ...  ...   ...
# 2235968  North America      US  Nevada  Las Vegas      5    9  2020
# 2235969  North America      US  Nevada  Las Vegas      5   10  2020
# 2235970  North America      US  Nevada  Las Vegas      5   11  2020
# 2235971  North America      US  Nevada  Las Vegas      5   12  2020
# 2235972  North America      US  Nevada  Las Vegas      5   13  2020
#
#          AvgTemperature
# 2217533            52.5
# 2217534            44.2
# 2217535            48.8
# 2217536            54.7
# ...

# %%
data_selected = data_prepared[data_prepared['City'].isin(["Reno", "Las Vegas","Portland"])]

# %%
data_selected.head()
# Out:
#                 Region Country  State      City  Month  Day  Year  \
# 2022879  North America      US  Maine  Portland      1    1  1995
# 2022880  North America      US  Maine  Portland      1    2  1995
# 2022881  North America      US  Maine  Portland      1    3  1995
# 2022882  North America      US  Maine  Portland      1    4  1995
# 2022883  North America      US  Maine  Portland      1    5  1995
#
#          AvgTemperature
# 2022879            32.2
# 2022880            31.5
# 2022881            23.9
# 2022882            23.8
# 2022883            12.9

# %%
data_selected.groupby(by='City').mean()
# Out:
#               Month        Day         Year  AvgTemperature
# City
# Las Vegas  6.468322  15.715812  2007.187372       69.840248
# Portland   6.468322  15.715812  2007.187372       50.403038
# Reno       6.468322  15.715812  2007.187372       54.074204

# %%
data_selected.groupby(by='City').max()
# Out:
#                   Region Country   State  Month  Day  Year  AvgTemperature
# City
# Las Vegas  North America      US  Nevada     12   31  2020           107.0
# Portland   North America      US  Oregon     12   31  2020            89.4
# Reno       North America      US  Nevada     12   31  2020            92.8

# %%
data_selected.groupby(by='City').agg(["min","max","mean"])
# Out:
#           Month               Day                 Year                     \
#             min max      mean min max       mean   min   max         mean
# City
# Las Vegas     1  12  6.468322   1  31  15.715812  1995  2020  2007.187372
# Portland      1  12  6.468322   1  31  15.715812  1995  2020  2007.187372
# Reno          1  12  6.468322   1  31  15.715812  1995  2020  2007.187372
#
#           AvgTemperature
#                      min    max       mean
# City
# Las Vegas          -99.0  107.0  69.840248
# Portland           -99.0   89.4  50.403038
# Reno               -99.0   92.8  54.074204

# %%
data_selected.head()
# Out:
#                 Region Country  State      City  Month  Day  Year  \
# 2022879  North America      US  Maine  Portland      1    1  1995
# 2022880  North America      US  Maine  Portland      1    2  1995
# 2022881  North America      US  Maine  Portland      1    3  1995
# 2022882  North America      US  Maine  Portland      1    4  1995
# 2022883  North America      US  Maine  Portland      1    5  1995
#
#          AvgTemperature
# 2022879            32.2
# 2022880            31.5
# 2022881            23.9
# 2022882            23.8
# 2022883            12.9

# %%
Reno_avg_temperatures = data_selected[data_selected['City'] == "Reno"]["AvgTemperature"]

# %%
LAsVegas_avg_temperatures = data_selected[data_selected['City'] == "Las Vegas"]["AvgTemperature"]

# %%
sns.distplot(Reno_avg_temperatures)
sns.distplot(LAsVegas_avg_temperatures)

# %%
data_selected.head()
# Out:
#                 Region Country  State      City  Month  Day  Year  \
# 2022879  North America      US  Maine  Portland      1    1  1995
# 2022880  North America      US  Maine  Portland      1    2  1995
# 2022881  North America      US  Maine  Portland      1    3  1995
# 2022882  North America      US  Maine  Portland      1    4  1995
# 2022883  North America      US  Maine  Portland      1    5  1995
#
#          AvgTemperature
# 2022879            32.2
# 2022880            31.5
# 2022881            23.9
# 2022882            23.8
# 2022883            12.9

# %%
data_selected['City'].value_counts().index
# Out:
# Index(['Portland', 'Las Vegas', 'Reno'], dtype='object')

# %%
Ulkeler = data_selected['City'].unique()

sns.set_style("whitegrid")
plt.figure(fgsize=(15,5))
for a in Ulkeler:
    data = data_selected[data_selected['City'] == "a"]["AvgTemperature"]
    sns.distplot(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-7b1b0c54997e> in <module>
#       2
#       3 sns.set_style("whitegrid")
# ----> 4 plt.figure(fgsize=(15,5))
#       5 for a in Ulkeler:
#       6     data = data_selected[data_selected['City'] == "a"]["AvgTemperature"]
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     538             dpi = 72
#     539
# --> 540         figManager = new_figure_manager(num, figsize=figsize,
#     541                                         dpi=dpi,
#     542                                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3355         from matplotlib.figure import Figure
# ...
