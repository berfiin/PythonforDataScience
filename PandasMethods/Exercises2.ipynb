# %%
import numpy as np
import pandas as pd

from pandas import DataFrame

# %%
df = pd.read_csv("veri_netflix.csv")

# %%
df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6234, step=1)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
yeni_etiket = {'show_id':'show_nu','type':'tip','title':'isim',
               'director':'yönetmen','cast':'kadro','country':'ülke',
               'date_added':'eklenme_tarihi','release_year':'vizyon_tarihi',
               'rating':'kanal','duration':'süre','listed_in':'kategori',
               'description':'aciklama'}

# %%
df.rename(columns=yeni_etiket,inplace=True)

# %%
df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
df.iloc[100]
# Out:
# show_nu                                                    81132443
# tip                                                           Movie
# isim                                                       Deliha 2
# yönetmen                                                 Gupse Özay
# kadro             Gupse Özay, Eda Ece, Aksel Bonfil, Derya Alabo...
# ülke                                                         Turkey
# eklenme_tarihi                                   September 27, 2019
# vizyon_tarihi                                                  2018
# kanal                                                         TV-PG
# süre                                                        102 min
# kategori                             Comedies, International Movies
# aciklama          While chasing her dream of becoming a chef, Ze...
# Name: 100, dtype: object

# %%
df.loc[100]
# Out:
# show_nu                                                    81132443
# tip                                                           Movie
# isim                                                       Deliha 2
# yönetmen                                                 Gupse Özay
# kadro             Gupse Özay, Eda Ece, Aksel Bonfil, Derya Alabo...
# ülke                                                         Turkey
# eklenme_tarihi                                   September 27, 2019
# vizyon_tarihi                                                  2018
# kanal                                                         TV-PG
# süre                                                        102 min
# kategori                             Comedies, International Movies
# aciklama          While chasing her dream of becoming a chef, Ze...
# Name: 100, dtype: object

# %%
df[['isim','yönetmen','kategori','süre']]
# Out:
#                                              isim                  yönetmen  \
# 0         Norm of the North: King Sized Adventure  Richard Finn, Tim Maltby
# 1                      Jandino: Whatever it Takes                       NaN
# 2                              Transformers Prime                       NaN
# 3                Transformers: Robots in Disguise                       NaN
# 4                                    #realityhigh          Fernando Lebrija
# ...                                           ...                       ...
# 6229                                 Red vs. Blue                       NaN
# 6230                                        Maron                       NaN
# 6231       Little Baby Bum: Nursery Rhyme Friends                       NaN
# 6232  A Young Doctor's Notebook and Other Stories                       NaN
# 6233                                      Friends                       NaN
#
# ...

# %%
IMDB = np.random.uniform(low=3.0, high=9.2, size=len(df['isim']))
IMDB = np.around(IMDB,decimals = 1)

# %%
df['IMDB_puan'] = IMDB #Ürettigimiz rast gele puanlari "IMDB_puan" sütunu olarak ekleyelim.
df.head()
# Out:
#     show_nu      tip                                     isim  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    yönetmen  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                kadro  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                        ülke     eklenme_tarihi  vizyon_tarihi  \
# ...

# %%
del df['yönetmen']

# %%
df.head()
# Out:
#     show_nu      tip                                     isim  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                                                kadro  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                        ülke     eklenme_tarihi  vizyon_tarihi  \
# 0  United States, India, South Korea, China  September 9, 2019           2019
# 1                            United Kingdom  September 9, 2016           2016
# ...

# %%
df.drop('eklenme_tarihi',axis=1)
# Out:
#        show_nu      tip                                         isim  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                                                   kadro  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# ...

# %%
df['IMDB_puan'].agg(['max','min','mean'])
# Out:
# max     9.200000
# min     3.000000
# mean    6.096952
# Name: IMDB_puan, dtype: float64

# %%
df['IMDB_puan'][df['IMDB_puan'] == 9.2].count() #imdb si 9.2 olan kaç tane  film
# Out:
# 49

# %%
df['isim'][df['IMDB_puan'] == 9.2].head()
# Out:
# 451              Private Life
# 783                      Blow
# 946       Justice in the City
# 951     My Life as a Zucchini
# 1107      True: Winter Wishes
# Name: isim, dtype: object

# %%
df.sort_values(by = 'IMDB_puan', ascending = False)
# Out:
#        show_nu      tip                                        isim  \
# 3094  70295560    Movie                           Bo Burnham: what.
# 3273  70279637    Movie                  Frozen Planet: On Thin Ice
# 5119  80041339    Movie                              The Diabolical
# 451   80168222    Movie                                Private Life
# 4492  70224999    Movie                                       Don 2
# ...        ...      ...                                         ...
# 5100  80997864    Movie                        Little Dragon Maiden
# 83    80199032  TV Show  Paul Hollywood's Big Continental Road Trip
# 120   81186757    Movie                            Oh! Baby (Tamil)
# 4056  80078037  TV Show                                Little Lunch
# 991   60022914    Movie                                Hard Lessons
#
#                                                   kadro  \
# 3094                                         Bo Burnham
# ...

# %%
df['IMDB_puan'].describe()
# Out:
# count    6234.000000
# mean        6.096952
# std         1.784949
# min         3.000000
# 25%         4.500000
# 50%         6.100000
# 75%         7.600000
# max         9.200000
# Name: IMDB_puan, dtype: float64

# %%
df[(df['IMDB_puan']>8) & (df['ülke']=='Turkey')]
# Out:
#        show_nu      tip                   isim  \
# 271   81132438    Movie          Locked on You
# 2257  80134521    Movie         Berlin Kaplani
# 2266  80038353    Movie          Eyyvah Eyyvah
# 2275  80134436    Movie              Kara Bela
# 2276  80134514    Movie      Kocan Kadar Konus
# 2278  80134520    Movie     Kurtulus Son Durak
# 4346  80037129  TV Show                   Ezel
# 4347  80037176  TV Show                  Kaçak
# 5223  80231064    Movie  Ali Baba ve 7 Cüceler
# 5224  80227118    Movie  Aşk Tesadüfleri Sever
# 5450  81043541    Movie  Dabbe: The Possession
# 5551  80123567  TV Show          Burned Cocoon
# 6212  80126877  TV Show                Filinta
#
#                                                   kadro    ülke  \
# 271   Ata Demirer, Demet Akbağ, Gonca Vuslateri, İlk...  Turkey
# 2257  Ata Demirer, Necati Bilgiç, Tarık Ünlüoğlu, Öz...  Turkey
# 2266  Demet Akbağ, Ata Demirer, Özge Borak, Bican Gü...  Turkey
# ...

# %%
df['vizyon_tarihi'].min()
# Out:
# 1925

# %%
df['vizyon_tarihi'].idxmin()
# Out:
# 4292

# %%
df.loc[4292,'isim']
# Out:
# 'Pioneers: First Women Filmmakers*'

# %%
df.isnull().sum()
# Out:
# show_nu             0
# tip                 0
# isim                0
# kadro             570
# ülke              476
# eklenme_tarihi     11
# vizyon_tarihi       0
# kanal              10
# süre                0
# kategori            0
# aciklama            0
# IMDB_puan           0
# dtype: int64

# %%
df.dropna()
# Out:
#        show_nu      tip                                     isim  \
# 0     81145628    Movie  Norm of the North: King Sized Adventure
# 1     80117401    Movie               Jandino: Whatever it Takes
# 2     70234439  TV Show                       Transformers Prime
# 3     80058654  TV Show         Transformers: Robots in Disguise
# 4     80125979    Movie                             #realityhigh
# ...        ...      ...                                      ...
# 6218  80162994  TV Show                  Talking Tom and Friends
# 6219  80186475  TV Show                       Pokémon the Series
# 6220  70272742  TV Show                              Justin Time
# 6221  80067942  TV Show  Terrace House: Boys & Girls in the City
# 6222  70136122  TV Show                                    Weeds
#
#                                                   kadro  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                      Jandino Asporaat
# ...

# %%
df.fillna(value ='mevcut degil')
# Out:
#        show_nu      tip                                         isim  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                                                   kadro  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# ...

# %%
df.fillna(method = 'ffill')
# Out:
#        show_nu      tip                                         isim  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                                                   kadro  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# ...

# %%
df['tip'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df['kanal'].unique()
# Out:
# array(['TV-PG', 'TV-MA', 'TV-Y7-FV', 'TV-Y7', 'TV-14', 'R', 'TV-Y', 'NR',
#        'PG-13', 'TV-G', 'PG', 'G', nan, 'UR', 'NC-17'], dtype=object)

# %%
pd.crosstab(df['tip'],df['kanal'])
# Out:
# kanal     G  NC-17   NR   PG  PG-13    R  TV-14  TV-G  TV-MA  TV-PG  TV-Y  \
# tip
# Movie    36      2  202  183    286  506   1038    80   1348    432    41
# TV Show   1      0   16    1      0    2    660    69    679    269   102
#
# kanal    TV-Y7  TV-Y7-FV  UR
# tip
# Movie       69        27   7
# TV Show    100        68   0

# %%
df.replace({'tip': {'movie' : 'Film', 'TV Show': 'TV Programi'}})
# Out:
#        show_nu          tip                                         isim  \
# 0     81145628        Movie      Norm of the North: King Sized Adventure
# 1     80117401        Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Programi                           Transformers Prime
# 3     80058654  TV Programi             Transformers: Robots in Disguise
# 4     80125979        Movie                                 #realityhigh
# ...        ...          ...                                          ...
# 6229  80000063  TV Programi                                 Red vs. Blue
# 6230  70286564  TV Programi                                        Maron
# 6231  80116008        Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Programi  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Programi                                      Friends
#
#                                                   kadro  \
# ...

# %%
grup = df['IMDB_puan'].groupby(df['kanal'])

# %%
grup

# %%
grup.mean().sort_values()#kanalları ortalama IMDB puanlarına göre sıralama
# Out:
# kanal
# TV-G        5.999329
# TV-PG       6.013980
# PG-13       6.025524
# PG          6.054348
# R           6.069488
# NR          6.087615
# TV-Y7       6.099408
# TV-14       6.112485
# TV-MA       6.123088
# UR          6.142857
# TV-Y        6.189510
# G           6.310811
# TV-Y7-FV    6.409474
# NC-17       6.500000
# Name: IMDB_puan, dtype: float64

# %%
def ikiyebol(ser):
   return ser/2.0

# %%
df['IMDB_puan'].apply(ikiyebol)
# Out:
# 0       2.45
# 1       2.65
# 2       3.45
# 3       3.60
# 4       1.80
#         ...
# 6229    1.65
# 6230    3.85
# 6231    2.10
# 6232    1.75
# 6233    2.60
# Name: IMDB_puan, Length: 6234, dtype: float64
